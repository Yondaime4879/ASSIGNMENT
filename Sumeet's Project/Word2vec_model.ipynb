# %%
import pandas as pd
import numpy as np
import nltk
data = pd.read_csv("category_headlines.csv")

# %%
data.head()
# Out:
#   Category                                           Sentence
# 0        b  Fed's Charles Plosser sees high bar for change...
# 1        b  US open: Stocks fall after Fed official hints ...
# 2        b  Fed's Plosser: Nasty Weather Has Curbed Job Gr...
# 3        b  Plosser: Fed May Have to Accelerate Tapering Pace
# 4        b          Fed's Plosser: Taper pace may be too slow

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size=0.2)

# %%
corpus = data['Sentence'].values.tolist()

# %%
len(corpus)
# Out:
# 340462

# %%
type(corpus[1])
# Out:
# str

# %%
import gensim
corp = [nltk.word_tokenize(sent.decode('utf-8')) for sent in corpus]

# %%
model = gensim.models.Word2Vec(corp,size=100, window=5, min_count=5, workers=4)

# %%
model.wv.most_similar('man')
# Out:
# [(u'woman', 0.8756951093673706),
#  (u'teen', 0.8756441473960876),
#  (u'girl', 0.8362553119659424),
#  (u'homeless', 0.8276714086532593),
#  (u'sick', 0.8218855857849121),
#  (u'police', 0.7983235120773315),
#  (u'mother', 0.7978066802024841),
#  (u'fan', 0.79427170753479),
#  (u'heroin', 0.7942607998847961),
#  (u'rare', 0.7912670969963074)]
